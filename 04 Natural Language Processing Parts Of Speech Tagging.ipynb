# %% [markdown]
# # In corpus linguistics, part-of-speech tagging (POS tagging or PoS tagging or POST), also called grammatical tagging or word-category disambiguation, is the process of marking up a word in a text (corpus) as corresponding to a particular part of speech, based on both its definition and its context—i.e., its relationship with adjacent and related words in a phrase, sentence, or paragraph. A simplified form of this is commonly taught to school-age children, in the identification of words as nouns, verbs, adjectives, adverbs, etc.

# %%
import nltk
import sys
import sklearn

# %%
paragraph = """
What are the qualities of your voice?
The Throat Center. {Chakra of the Month}
Mine is usually calm, soothing and clear. Yoga students often tell me my voice is relaxing, which is a sweet compliment. However, when I’m caught up in a moment of anger, fear or stress, my voice can get sharp and sound anything but calm and relaxing.

Let’s bring more mindfulness to our voices and how we use them this month. Our December chakra focus is our communication center, the throat center.
Just joining in? Read about the first, second, third and fourth chakras.

Chakra author Anothea Judith writes:
Vaguely Relephant Reads:

You Don’t have to be an Alcoholic to be Wasted. Read 

How to Get Over the One you Can’t Get Over. Read 

Chakra five is the center related to communication through sound, vibration, self-expression and creativity.
It is the realm of consciousness that controls, creates, transmits and receives communication, both within ourselves and between each other.
It is the center of dynamic creativity, of synthesizing old ideas into something new.
The fifth chakra color is bright, cerulean or turquoise blue.
Some symptoms of an out-of-balance fifth chakra include suffering from throat-centered illnesses, like strep throat or losing our voice.
Throaty ailments may mean we need to slow down, rest and communicate more clearly, both with ourselves and others, or they may be a result of excess communication or over-sharing—and a sign that we should give our voice a break and intentionally soak in silence.
If our lives are busy, we need to relax and remember how to set boundaries, express our needs and allow time and space to nurture ourselves.
When our throat chakra is healthy and balanced, we express ourselves and communicate clearly, honestly and openly—but not excessively.
Here are some other ways to help balance and align our throat chakra:
Chant
Any time we speak, sing, scream, whisper or make any other sort of sound with our voice, we invoke throat energy. The element of vishuddha chakra is sound, so belt out some long OMs, or whatever other chants you like.
Asana
Warm up by practicing gentle neck stretches in all directions. Many heart openers/back bends are also throat openers. The ultimate is probably fish pose (matsyasana).
Experiment with Music
Try practicing yoga or meditation to healing sounds like Tibetan singing bowls, African drums, ocean waves, rock music—and sometimes in sweet silence.
Mantra Meditation
Perfect for sitting, standing or walking meditation, repeating a silent mantra is a form of meditation that helps us quickly focus and calm the mind. It can be a syllable sound like “Om” or a word or phrase in Sanskrit, English or whatever language you prefer. A nice one is “sat nam,” which means “I am the truth,” in Sanskrit, but there are millions to choose from.
Mindfully Drink Tea
Brew up a mugful of your favorite herbal tea and have your own little ceremony as you meditate and enjoy a delicious, soothing hot drink.
Express Yourself
Speak up! Share something about yourself with someone. Write a poem. Sing. Express your unique voice in whatever way you wish.
On that note, if you’d like to participate in a two-week writing challenge this month, check out the reverb13 community writing project happening here at elephant."""

# %%
words = nltk.word_tokenize(paragraph)

# %%
words
# Out:
# ['What',
#  'are',
#  'the',
#  'qualities',
#  'of',
#  'your',
#  'voice',
#  '?',
#  'The',
#  'Throat',
#  'Center',
#  '.',
#  '{',
#  'Chakra',
#  'of',
#  'the',
#  'Month',
#  '}',
#  'Mine',
#  'is',
#  'usually',
#  'calm',
#  ',',
#  'soothing',
#  'and',
#  'clear',
#  '.',
#  'Yoga',
#  'students',
#  'often',
#  'tell',
#  'me',
#  'my',
#  'voice',
#  'is',
#  'relaxing',
#  ',',
#  'which',
#  'is',
#  'a',
#  'sweet',
#  'compliment',
#  '.',
#  'However',
#  ',',
#  'when',
#  'I',
#  '’',
#  'm',
#  'caught',
#  'up',
#  'in',
#  'a',
#  'moment',
#  'of',
#  'anger',
#  ',',
#  'fear',
#  'or',
#  'stress',
#  ',',
#  'my',
#  'voice',
#  'can',
#  'get',
#  'sharp',
#  'and',
#  'sound',
#  'anything',
#  'but',
#  'calm',
#  'and',
#  'relaxing',
#  '.',
#  'Let',
#  '’',
#  's',
#  'bring',
#  'more',
#  'mindfulness',
#  'to',
#  'our',
#  'voices',
#  'and',
#  'how',
#  'we',
#  'use',
#  'them',
#  'this',
#  'month',
#  '.',
#  'Our',
#  'December',
#  'chakra',
#  'focus',
#  'is',
#  'our',
#  'communication',
#  'center',
#  ',',
#  'the',
#  'throat',
#  'center',
#  '.',
#  'Just',
#  'joining',
#  'in',
#  '?',
#  'Read',
#  'about',
#  'the',
#  'first',
#  ',',
#  'second',
#  ',',
#  'third',
#  'and',
#  'fourth',
#  'chakras',
#  '.',
#  'Chakra',
#  'author',
#  'Anothea',
#  'Judith',
#  'writes',
#  ':',
#  'Vaguely',
#  'Relephant',
#  'Reads',
#  ':',
#  'You',
#  'Don',
#  '’',
#  't',
#  'have',
#  'to',
#  'be',
#  'an',
#  'Alcoholic',
#  'to',
#  'be',
#  'Wasted',
#  '.',
#  'Read',
#  'How',
#  'to',
#  'Get',
#  'Over',
#  'the',
#  'One',
#  'you',
#  'Can',
#  '’',
#  't',
#  'Get',
#  'Over',
#  '.',
#  'Read',
#  'Chakra',
#  'five',
#  'is',
#  'the',
#  'center',
#  'related',
#  'to',
#  'communication',
#  'through',
#  'sound',
#  ',',
#  'vibration',
#  ',',
#  'self-expression',
#  'and',
#  'creativity',
#  '.',
#  'It',
#  'is',
#  'the',
#  'realm',
#  'of',
#  'consciousness',
#  'that',
#  'controls',
#  ',',
#  'creates',
#  ',',
#  'transmits',
#  'and',
#  'receives',
#  'communication',
#  ',',
#  'both',
#  'within',
#  'ourselves',
#  'and',
#  'between',
#  'each',
#  'other',
#  '.',
#  'It',
#  'is',
#  'the',
#  'center',
#  'of',
#  'dynamic',
#  'creativity',
#  ',',
#  'of',
#  'synthesizing',
#  'old',
#  'ideas',
#  'into',
#  'something',
#  'new',
#  '.',
#  'The',
#  'fifth',
#  'chakra',
#  'color',
#  'is',
#  'bright',
#  ',',
#  'cerulean',
#  'or',
#  'turquoise',
#  'blue',
#  '.',
#  'Some',
#  'symptoms',
#  'of',
#  'an',
#  'out-of-balance',
#  'fifth',
#  'chakra',
#  'include',
#  'suffering',
#  'from',
#  'throat-centered',
#  'illnesses',
#  ',',
#  'like',
#  'strep',
#  'throat',
#  'or',
#  'losing',
#  'our',
#  'voice',
#  '.',
#  'Throaty',
#  'ailments',
#  'may',
#  'mean',
#  'we',
#  'need',
#  'to',
#  'slow',
#  'down',
#  ',',
#  'rest',
#  'and',
#  'communicate',
#  'more',
#  'clearly',
#  ',',
#  'both',
#  'with',
#  'ourselves',
#  'and',
#  'others',
#  ',',
#  'or',
#  'they',
#  'may',
#  'be',
#  'a',
#  'result',
#  'of',
#  'excess',
#  'communication',
#  'or',
#  'over-sharing—and',
#  'a',
#  'sign',
#  'that',
#  'we',
#  'should',
#  'give',
#  'our',
#  'voice',
#  'a',
#  'break',
#  'and',
#  'intentionally',
#  'soak',
#  'in',
#  'silence',
#  '.',
#  'If',
#  'our',
#  'lives',
#  'are',
#  'busy',
#  ',',
#  'we',
#  'need',
#  'to',
#  'relax',
#  'and',
#  'remember',
#  'how',
#  'to',
#  'set',
#  'boundaries',
#  ',',
#  'express',
#  'our',
#  'needs',
#  'and',
#  'allow',
#  'time',
#  'and',
#  'space',
#  'to',
#  'nurture',
#  'ourselves',
#  '.',
#  'When',
#  'our',
#  'throat',
#  'chakra',
#  'is',
#  'healthy',
#  'and',
#  'balanced',
#  ',',
#  'we',
#  'express',
#  'ourselves',
#  'and',
#  'communicate',
#  'clearly',
#  ',',
#  'honestly',
#  'and',
#  'openly—but',
#  'not',
#  'excessively',
#  '.',
#  'Here',
#  'are',
#  'some',
#  'other',
#  'ways',
#  'to',
#  'help',
#  'balance',
#  'and',
#  'align',
#  'our',
#  'throat',
#  'chakra',
#  ':',
#  'Chant',
#  'Any',
#  'time',
#  'we',
#  'speak',
#  ',',
#  'sing',
#  ',',
#  'scream',
#  ',',
#  'whisper',
#  'or',
#  'make',
#  'any',
#  'other',
#  'sort',
#  'of',
#  'sound',
#  'with',
#  'our',
#  'voice',
#  ',',
#  'we',
#  'invoke',
#  'throat',
#  'energy',
#  '.',
#  'The',
#  'element',
#  'of',
#  'vishuddha',
#  'chakra',
#  'is',
#  'sound',
#  ',',
#  'so',
#  'belt',
#  'out',
#  'some',
#  'long',
#  'OMs',
#  ',',
#  'or',
#  'whatever',
#  'other',
#  'chants',
#  'you',
#  'like',
#  '.',
#  'Asana',
#  'Warm',
#  'up',
#  'by',
#  'practicing',
#  'gentle',
#  'neck',
#  'stretches',
#  'in',
#  'all',
#  'directions',
#  '.',
#  'Many',
#  'heart',
#  'openers/back',
#  'bends',
#  'are',
#  'also',
#  'throat',
#  'openers',
#  '.',
#  'The',
#  'ultimate',
#  'is',
#  'probably',
#  'fish',
#  'pose',
#  '(',
#  'matsyasana',
#  ')',
#  '.',
#  'Experiment',
#  'with',
#  'Music',
#  'Try',
#  'practicing',
#  'yoga',
#  'or',
#  'meditation',
#  'to',
#  'healing',
#  'sounds',
#  'like',
#  'Tibetan',
#  'singing',
#  'bowls',
#  ',',
#  'African',
#  'drums',
#  ',',
#  'ocean',
#  'waves',
#  ',',
#  'rock',
#  'music—and',
#  'sometimes',
#  'in',
#  'sweet',
#  'silence',
#  '.',
#  'Mantra',
#  'Meditation',
#  'Perfect',
#  'for',
#  'sitting',
#  ',',
#  'standing',
#  'or',
#  'walking',
#  'meditation',
#  ',',
#  'repeating',
#  'a',
#  'silent',
#  'mantra',
#  'is',
#  'a',
#  'form',
#  'of',
#  'meditation',
#  'that',
#  'helps',
#  'us',
#  'quickly',
#  'focus',
#  'and',
#  'calm',
#  'the',
#  'mind',
#  '.',
#  'It',
#  'can',
#  'be',
#  'a',
#  'syllable',
#  'sound',
#  'like',
#  '“',
#  'Om',
#  '”',
#  'or',
#  'a',
#  'word',
#  'or',
#  'phrase',
#  'in',
#  'Sanskrit',
#  ',',
#  'English',
#  'or',
#  'whatever',
#  'language',
#  'you',
#  'prefer',
#  '.',
#  'A',
#  'nice',
#  'one',
#  'is',
#  '“',
#  'sat',
#  'nam',
#  ',',
#  '”',
#  'which',
#  'means',
#  '“',
#  'I',
#  'am',
#  'the',
#  'truth',
#  ',',
#  '”',
#  'in',
#  'Sanskrit',
#  ',',
#  'but',
#  'there',
#  'are',
#  'millions',
#  'to',
#  'choose',
#  'from',
#  '.',
#  'Mindfully',
#  'Drink',
#  'Tea',
#  'Brew',
#  'up',
#  'a',
#  'mugful',
#  'of',
#  'your',
#  'favorite',
#  'herbal',
#  'tea',
#  'and',
#  'have',
#  'your',
#  'own',
#  'little',
#  'ceremony',
#  'as',
#  'you',
#  'meditate',
#  'and',
#  'enjoy',
#  'a',
#  'delicious',
#  ',',
#  'soothing',
#  'hot',
#  'drink',
#  '.',
#  'Express',
#  'Yourself',
#  'Speak',
#  'up',
#  '!',
#  'Share',
#  'something',
#  'about',
#  'yourself',
#  'with',
#  'someone',
#  '.',
#  'Write',
#  'a',
#  'poem',
#  '.',
#  'Sing',
#  '.',
#  'Express',
#  'your',
#  'unique',
#  'voice',
#  'in',
#  'whatever',
#  'way',
#  'you',
#  'wish',
#  '.',
#  'On',
#  'that',
#  'note',
#  ',',
#  'if',
#  'you',
#  '’',
#  'd',
#  'like',
#  'to',
#  'participate',
#  'in',
#  'a',
#  'two-week',
#  'writing',
#  'challenge',
#  'this',
#  'month',
#  ',',
#  'check',
#  'out',
#  'the',
#  'reverb13',
#  'community',
#  'writing',
#  'project',
#  'happening',
#  'here',
#  'at',
#  'elephant',
#  '.']

# %%
# We will create a variable called Tagged Words along with their parts of speech

# %%
tagged_words = nltk.pos_tag(words)
tagged_words
# Out:
# [('What', 'WP'),
#  ('are', 'VBP'),
#  ('the', 'DT'),
#  ('qualities', 'NNS'),
#  ('of', 'IN'),
#  ('your', 'PRP$'),
#  ('voice', 'NN'),
#  ('?', '.'),
#  ('The', 'DT'),
#  ('Throat', 'NNP'),
#  ('Center', 'NNP'),
#  ('.', '.'),
#  ('{', '('),
#  ('Chakra', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Month', 'NNP'),
#  ('}', ')'),
#  ('Mine', 'NNP'),
#  ('is', 'VBZ'),
#  ('usually', 'RB'),
#  ('calm', 'JJ'),
#  (',', ','),
#  ('soothing', 'JJ'),
#  ('and', 'CC'),
#  ('clear', 'JJ'),
#  ('.', '.'),
#  ('Yoga', 'JJ'),
#  ('students', 'NNS'),
#  ('often', 'RB'),
#  ('tell', 'VBP'),
#  ('me', 'PRP'),
#  ('my', 'PRP$'),
#  ('voice', 'NN'),
#  ('is', 'VBZ'),
#  ('relaxing', 'VBG'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('sweet', 'JJ'),
#  ('compliment', 'NN'),
#  ('.', '.'),
#  ('However', 'RB'),
#  (',', ','),
#  ('when', 'WRB'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'RB'),
#  ('caught', 'VBN'),
#  ('up', 'RP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('moment', 'NN'),
#  ('of', 'IN'),
#  ('anger', 'NN'),
#  (',', ','),
#  ('fear', 'NN'),
#  ('or', 'CC'),
#  ('stress', 'NN'),
#  (',', ','),
#  ('my', 'PRP$'),
#  ('voice', 'NN'),
#  ('can', 'MD'),
#  ('get', 'VB'),
#  ('sharp', 'JJ'),
#  ('and', 'CC'),
#  ('sound', 'JJ'),
#  ('anything', 'NN'),
#  ('but', 'CC'),
#  ('calm', 'NN'),
#  ('and', 'CC'),
#  ('relaxing', 'NN'),
#  ('.', '.'),
#  ('Let', 'VB'),
#  ('’', 'NNP'),
#  ('s', 'VB'),
#  ('bring', 'VBG'),
#  ('more', 'JJR'),
#  ('mindfulness', 'NN'),
#  ('to', 'TO'),
#  ('our', 'PRP$'),
#  ('voices', 'NNS'),
#  ('and', 'CC'),
#  ('how', 'WRB'),
#  ('we', 'PRP'),
#  ('use', 'VBP'),
#  ('them', 'PRP'),
#  ('this', 'DT'),
#  ('month', 'NN'),
#  ('.', '.'),
#  ('Our', 'PRP$'),
#  ('December', 'NNP'),
#  ('chakra', 'NN'),
#  ('focus', 'NN'),
#  ('is', 'VBZ'),
#  ('our', 'PRP$'),
#  ('communication', 'NN'),
#  ('center', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('throat', 'NN'),
#  ('center', 'NN'),
#  ('.', '.'),
#  ('Just', 'NNP'),
#  ('joining', 'VBG'),
#  ('in', 'IN'),
#  ('?', '.'),
#  ('Read', 'VB'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  (',', ','),
#  ('second', 'JJ'),
#  (',', ','),
#  ('third', 'JJ'),
#  ('and', 'CC'),
#  ('fourth', 'JJ'),
#  ('chakras', 'NNS'),
#  ('.', '.'),
#  ('Chakra', 'NNP'),
#  ('author', 'NN'),
#  ('Anothea', 'NNP'),
#  ('Judith', 'NNP'),
#  ('writes', 'VBZ'),
#  (':', ':'),
#  ('Vaguely', 'RB'),
#  ('Relephant', 'JJ'),
#  ('Reads', 'NNS'),
#  (':', ':'),
#  ('You', 'PRP'),
#  ('Don', 'VBP'),
#  ('’', 'JJ'),
#  ('t', 'NNS'),
#  ('have', 'VBP'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('an', 'DT'),
#  ('Alcoholic', 'NNP'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('Wasted', 'VBN'),
#  ('.', '.'),
#  ('Read', 'VB'),
#  ('How', 'WRB'),
#  ('to', 'TO'),
#  ('Get', 'VB'),
#  ('Over', 'IN'),
#  ('the', 'DT'),
#  ('One', 'CD'),
#  ('you', 'PRP'),
#  ('Can', 'MD'),
#  ('’', 'VB'),
#  ('t', 'JJ'),
#  ('Get', 'NNP'),
#  ('Over', 'NNP'),
#  ('.', '.'),
#  ('Read', 'NNP'),
#  ('Chakra', 'NNP'),
#  ('five', 'CD'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('center', 'NN'),
#  ('related', 'VBN'),
#  ('to', 'TO'),
#  ('communication', 'NN'),
#  ('through', 'IN'),
#  ('sound', 'NN'),
#  (',', ','),
#  ('vibration', 'NN'),
#  (',', ','),
#  ('self-expression', 'NN'),
#  ('and', 'CC'),
#  ('creativity', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('realm', 'NN'),
#  ('of', 'IN'),
#  ('consciousness', 'NN'),
#  ('that', 'WDT'),
#  ('controls', 'VBZ'),
#  (',', ','),
#  ('creates', 'NNS'),
#  (',', ','),
#  ('transmits', 'NNS'),
#  ('and', 'CC'),
#  ('receives', 'NNS'),
#  ('communication', 'NN'),
#  (',', ','),
#  ('both', 'DT'),
#  ('within', 'IN'),
#  ('ourselves', 'PRP'),
#  ('and', 'CC'),
#  ('between', 'IN'),
#  ('each', 'DT'),
#  ('other', 'JJ'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('center', 'NN'),
#  ('of', 'IN'),
#  ('dynamic', 'JJ'),
#  ('creativity', 'NN'),
#  (',', ','),
#  ('of', 'IN'),
#  ('synthesizing', 'VBG'),
#  ('old', 'JJ'),
#  ('ideas', 'NNS'),
#  ('into', 'IN'),
#  ('something', 'NN'),
#  ('new', 'JJ'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('fifth', 'JJ'),
#  ('chakra', 'NN'),
#  ('color', 'NN'),
#  ('is', 'VBZ'),
#  ('bright', 'JJ'),
#  (',', ','),
#  ('cerulean', 'JJ'),
#  ('or', 'CC'),
#  ('turquoise', 'JJ'),
#  ('blue', 'NN'),
#  ('.', '.'),
#  ('Some', 'DT'),
#  ('symptoms', 'NNS'),
#  ('of', 'IN'),
#  ('an', 'DT'),
#  ('out-of-balance', 'JJ'),
#  ('fifth', 'NN'),
#  ('chakra', 'NN'),
#  ('include', 'VBP'),
#  ('suffering', 'VBG'),
#  ('from', 'IN'),
#  ('throat-centered', 'JJ'),
#  ('illnesses', 'NNS'),
#  (',', ','),
#  ('like', 'IN'),
#  ('strep', 'JJ'),
#  ('throat', 'NN'),
#  ('or', 'CC'),
#  ('losing', 'VBG'),
#  ('our', 'PRP$'),
#  ('voice', 'NN'),
#  ('.', '.'),
#  ('Throaty', 'NNP'),
#  ('ailments', 'NNS'),
#  ('may', 'MD'),
#  ('mean', 'VB'),
#  ('we', 'PRP'),
#  ('need', 'VBP'),
#  ('to', 'TO'),
#  ('slow', 'VB'),
#  ('down', 'RP'),
#  (',', ','),
#  ('rest', 'NN'),
#  ('and', 'CC'),
#  ('communicate', 'VB'),
#  ('more', 'JJR'),
#  ('clearly', 'RB'),
#  (',', ','),
#  ('both', 'DT'),
#  ('with', 'IN'),
#  ('ourselves', 'NNS'),
#  ('and', 'CC'),
#  ('others', 'NNS'),
#  (',', ','),
#  ('or', 'CC'),
#  ('they', 'PRP'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('result', 'NN'),
#  ('of', 'IN'),
#  ('excess', 'JJ'),
#  ('communication', 'NN'),
#  ('or', 'CC'),
#  ('over-sharing—and', 'VB'),
#  ('a', 'DT'),
#  ('sign', 'NN'),
#  ('that', 'IN'),
#  ('we', 'PRP'),
#  ('should', 'MD'),
#  ('give', 'VB'),
#  ('our', 'PRP$'),
#  ('voice', 'NN'),
#  ('a', 'DT'),
#  ('break', 'NN'),
#  ('and', 'CC'),
#  ('intentionally', 'RB'),
#  ('soak', 'VB'),
#  ('in', 'IN'),
#  ('silence', 'NN'),
#  ('.', '.'),
#  ('If', 'IN'),
#  ('our', 'PRP$'),
#  ('lives', 'NNS'),
#  ('are', 'VBP'),
#  ('busy', 'JJ'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('need', 'VBP'),
#  ('to', 'TO'),
#  ('relax', 'VB'),
#  ('and', 'CC'),
#  ('remember', 'VB'),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('set', 'VB'),
#  ('boundaries', 'NNS'),
#  (',', ','),
#  ('express', 'VB'),
#  ('our', 'PRP$'),
#  ('needs', 'NNS'),
#  ('and', 'CC'),
#  ('allow', 'VB'),
#  ('time', 'NN'),
#  ('and', 'CC'),
#  ('space', 'NN'),
#  ('to', 'TO'),
#  ('nurture', 'VB'),
#  ('ourselves', 'PRP'),
#  ('.', '.'),
#  ('When', 'WRB'),
#  ('our', 'PRP$'),
#  ('throat', 'NN'),
#  ('chakra', 'NN'),
#  ('is', 'VBZ'),
#  ('healthy', 'JJ'),
#  ('and', 'CC'),
#  ('balanced', 'JJ'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('express', 'VBP'),
#  ('ourselves', 'PRP'),
#  ('and', 'CC'),
#  ('communicate', 'VB'),
#  ('clearly', 'RB'),
#  (',', ','),
#  ('honestly', 'RB'),
#  ('and', 'CC'),
#  ('openly—but', 'MD'),
#  ('not', 'RB'),
#  ('excessively', 'RB'),
#  ('.', '.'),
#  ('Here', 'RB'),
#  ('are', 'VBP'),
#  ('some', 'DT'),
#  ('other', 'JJ'),
#  ('ways', 'NNS'),
#  ('to', 'TO'),
#  ('help', 'VB'),
#  ('balance', 'NN'),
#  ('and', 'CC'),
#  ('align', 'VB'),
#  ('our', 'PRP$'),
#  ('throat', 'NN'),
#  ('chakra', 'NN'),
#  (':', ':'),
#  ('Chant', 'NNP'),
#  ('Any', 'NNP'),
#  ('time', 'NN'),
#  ('we', 'PRP'),
#  ('speak', 'VBP'),
#  (',', ','),
#  ('sing', 'VBG'),
#  (',', ','),
#  ('scream', 'NN'),
#  (',', ','),
#  ('whisper', 'NN'),
#  ('or', 'CC'),
#  ('make', 'VB'),
#  ('any', 'DT'),
#  ('other', 'JJ'),
#  ('sort', 'NN'),
#  ('of', 'IN'),
#  ('sound', 'NN'),
#  ('with', 'IN'),
#  ('our', 'PRP$'),
#  ('voice', 'NN'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('invoke', 'VBP'),
#  ('throat', 'JJ'),
#  ('energy', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('element', 'NN'),
#  ('of', 'IN'),
#  ('vishuddha', 'NN'),
#  ('chakra', 'NN'),
#  ('is', 'VBZ'),
#  ('sound', 'JJ'),
#  (',', ','),
#  ('so', 'RB'),
#  ('belt', 'VBD'),
#  ('out', 'RP'),
#  ('some', 'DT'),
#  ('long', 'JJ'),
#  ('OMs', 'NNP'),
#  (',', ','),
#  ('or', 'CC'),
#  ('whatever', 'WDT'),
#  ('other', 'JJ'),
#  ('chants', 'NNS'),
#  ('you', 'PRP'),
#  ('like', 'VBP'),
#  ('.', '.'),
#  ('Asana', 'NNP'),
#  ('Warm', 'NNP'),
#  ('up', 'RP'),
#  ('by', 'IN'),
#  ('practicing', 'VBG'),
#  ('gentle', 'JJ'),
#  ('neck', 'NN'),
#  ('stretches', 'NNS'),
#  ('in', 'IN'),
#  ('all', 'DT'),
#  ('directions', 'NNS'),
#  ('.', '.'),
#  ('Many', 'JJ'),
#  ('heart', 'NN'),
#  ('openers/back', 'NN'),
#  ('bends', 'NNS'),
#  ('are', 'VBP'),
#  ('also', 'RB'),
#  ('throat', 'JJ'),
#  ('openers', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('ultimate', 'NN'),
#  ('is', 'VBZ'),
#  ('probably', 'RB'),
#  ('fish', 'JJ'),
#  ('pose', 'NN'),
#  ('(', '('),
#  ('matsyasana', 'NN'),
#  (')', ')'),
#  ('.', '.'),
#  ('Experiment', 'NN'),
#  ('with', 'IN'),
#  ('Music', 'NNP'),
#  ('Try', 'NNP'),
#  ('practicing', 'VBG'),
#  ('yoga', 'NN'),
#  ('or', 'CC'),
#  ('meditation', 'NN'),
#  ('to', 'TO'),
#  ('healing', 'VBG'),
#  ('sounds', 'NNS'),
#  ('like', 'IN'),
#  ('Tibetan', 'NNP'),
#  ('singing', 'VBG'),
#  ('bowls', 'NN'),
#  (',', ','),
#  ('African', 'NNP'),
#  ('drums', 'NNS'),
#  (',', ','),
#  ('ocean', 'JJ'),
#  ('waves', 'NNS'),
#  (',', ','),
#  ('rock', 'NN'),
#  ('music—and', 'NN'),
#  ('sometimes', 'RB'),
#  ('in', 'IN'),
#  ('sweet', 'JJ'),
#  ('silence', 'NN'),
#  ('.', '.'),
#  ('Mantra', 'NNP'),
#  ('Meditation', 'NNP'),
#  ('Perfect', 'NNP'),
#  ('for', 'IN'),
#  ('sitting', 'VBG'),
#  (',', ','),
#  ('standing', 'VBG'),
#  ('or', 'CC'),
#  ('walking', 'VBG'),
#  ('meditation', 'NN'),
#  (',', ','),
#  ('repeating', 'VBG'),
#  ('a', 'DT'),
#  ('silent', 'JJ'),
#  ('mantra', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('form', 'NN'),
#  ('of', 'IN'),
#  ('meditation', 'NN'),
#  ('that', 'WDT'),
#  ('helps', 'VBZ'),
#  ('us', 'PRP'),
#  ('quickly', 'RB'),
#  ('focus', 'VB'),
#  ('and', 'CC'),
#  ('calm', 'VB'),
#  ('the', 'DT'),
#  ('mind', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('syllable', 'JJ'),
#  ('sound', 'NN'),
#  ('like', 'IN'),
#  ('“', 'NNP'),
#  ('Om', 'NNP'),
#  ('”', 'NNP'),
#  ('or', 'CC'),
#  ('a', 'DT'),
#  ('word', 'NN'),
#  ('or', 'CC'),
#  ('phrase', 'NN'),
#  ('in', 'IN'),
#  ('Sanskrit', 'NNP'),
#  (',', ','),
#  ('English', 'NNP'),
#  ('or', 'CC'),
#  ('whatever', 'WDT'),
#  ('language', 'NN'),
#  ('you', 'PRP'),
#  ('prefer', 'VBP'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('nice', 'JJ'),
#  ('one', 'CD'),
#  ('is', 'VBZ'),
#  ('“', 'JJ'),
#  ('sat', 'JJ'),
#  ('nam', 'NN'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('which', 'WDT'),
#  ('means', 'VBZ'),
#  ('“', 'NN'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('the', 'DT'),
#  ('truth', 'NN'),
#  (',', ','),
#  ('”', 'NN'),
#  ('in', 'IN'),
#  ('Sanskrit', 'NNP'),
#  (',', ','),
#  ('but', 'CC'),
#  ('there', 'EX'),
#  ('are', 'VBP'),
#  ('millions', 'NNS'),
#  ('to', 'TO'),
#  ('choose', 'VB'),
#  ('from', 'IN'),
#  ('.', '.'),
#  ('Mindfully', 'NNP'),
#  ('Drink', 'NNP'),
#  ('Tea', 'NNP'),
#  ('Brew', 'NNP'),
#  ('up', 'RP'),
#  ('a', 'DT'),
#  ('mugful', 'NN'),
#  ('of', 'IN'),
#  ('your', 'PRP$'),
#  ('favorite', 'JJ'),
#  ('herbal', 'JJ'),
#  ('tea', 'NN'),
#  ('and', 'CC'),
#  ('have', 'VB'),
#  ('your', 'PRP$'),
#  ('own', 'JJ'),
#  ('little', 'JJ'),
#  ('ceremony', 'NN'),
#  ('as', 'IN'),
#  ('you', 'PRP'),
#  ('meditate', 'VBP'),
#  ('and', 'CC'),
#  ('enjoy', 'VBP'),
#  ('a', 'DT'),
#  ('delicious', 'JJ'),
#  (',', ','),
#  ('soothing', 'VBG'),
#  ('hot', 'JJ'),
#  ('drink', 'NN'),
#  ('.', '.'),
#  ('Express', 'NNP'),
#  ('Yourself', 'PRP'),
#  ('Speak', 'NNP'),
#  ('up', 'RP'),
#  ('!', '.'),
#  ('Share', 'NNP'),
#  ('something', 'NN'),
#  ('about', 'IN'),
#  ('yourself', 'PRP'),
#  ('with', 'IN'),
#  ('someone', 'NN'),
#  ('.', '.'),
#  ('Write', 'VB'),
#  ('a', 'DT'),
#  ('poem', 'NN'),
#  ('.', '.'),
#  ('Sing', 'VBG'),
#  ('.', '.'),
#  ('Express', 'VB'),
#  ('your', 'PRP$'),
#  ('unique', 'JJ'),
#  ('voice', 'NN'),
#  ('in', 'IN'),
#  ('whatever', 'WDT'),
#  ('way', 'NN'),
#  ('you', 'PRP'),
#  ('wish', 'VBP'),
#  ('.', '.'),
#  ('On', 'IN'),
#  ('that', 'DT'),
#  ('note', 'NN'),
#  (',', ','),
#  ('if', 'IN'),
#  ('you', 'PRP'),
#  ('’', 'VBP'),
#  ('d', 'NNS'),
#  ('like', 'IN'),
#  ('to', 'TO'),
#  ('participate', 'VB'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('two-week', 'JJ'),
#  ('writing', 'NN'),
#  ('challenge', 'NN'),
#  ('this', 'DT'),
#  ('month', 'NN'),
#  (',', ','),
#  ('check', 'VB'),
#  ('out', 'RP'),
#  ('the', 'DT'),
#  ('reverb13', 'NN'),
#  ('community', 'NN'),
#  ('writing', 'VBG'),
#  ('project', 'NN'),
#  ('happening', 'VBG'),
#  ('here', 'RB'),
#  ('at', 'IN'),
#  ('elephant', 'NN'),
#  ('.', '.')]

# %%
type(tagged_words)
# Out:
# list

# %%
print("Length of words",len(words))
print("Length of Tagged words is ",len(tagged_words))
# Out:
# Length of words 644
# Length of Tagged words is  644

# %%
# We need to append the words with their respective parts of speech
words_tags = []
for tw in tagged_words:
    words_tags.append(tw[0]+"_"+ tw[1])

# %%
words_tags
# Out:
# ['What_WP',
#  'are_VBP',
#  'the_DT',
#  'qualities_NNS',
#  'of_IN',
#  'your_PRP$',
#  'voice_NN',
#  '?_.',
#  'The_DT',
#  'Throat_NNP',
#  'Center_NNP',
#  '._.',
#  '{_(',
#  'Chakra_NNP',
#  'of_IN',
#  'the_DT',
#  'Month_NNP',
#  '}_)',
#  'Mine_NNP',
#  'is_VBZ',
#  'usually_RB',
#  'calm_JJ',
#  ',_,',
#  'soothing_JJ',
#  'and_CC',
#  'clear_JJ',
#  '._.',
#  'Yoga_JJ',
#  'students_NNS',
#  'often_RB',
#  'tell_VBP',
#  'me_PRP',
#  'my_PRP$',
#  'voice_NN',
#  'is_VBZ',
#  'relaxing_VBG',
#  ',_,',
#  'which_WDT',
#  'is_VBZ',
#  'a_DT',
#  'sweet_JJ',
#  'compliment_NN',
#  '._.',
#  'However_RB',
#  ',_,',
#  'when_WRB',
#  'I_PRP',
#  '’_VBP',
#  'm_RB',
#  'caught_VBN',
#  'up_RP',
#  'in_IN',
#  'a_DT',
#  'moment_NN',
#  'of_IN',
#  'anger_NN',
#  ',_,',
#  'fear_NN',
#  'or_CC',
#  'stress_NN',
#  ',_,',
#  'my_PRP$',
#  'voice_NN',
#  'can_MD',
#  'get_VB',
#  'sharp_JJ',
#  'and_CC',
#  'sound_JJ',
#  'anything_NN',
#  'but_CC',
#  'calm_NN',
#  'and_CC',
#  'relaxing_NN',
#  '._.',
#  'Let_VB',
#  '’_NNP',
#  's_VB',
#  'bring_VBG',
#  'more_JJR',
#  'mindfulness_NN',
#  'to_TO',
#  'our_PRP$',
#  'voices_NNS',
#  'and_CC',
#  'how_WRB',
#  'we_PRP',
#  'use_VBP',
#  'them_PRP',
#  'this_DT',
#  'month_NN',
#  '._.',
#  'Our_PRP$',
#  'December_NNP',
#  'chakra_NN',
#  'focus_NN',
#  'is_VBZ',
#  'our_PRP$',
#  'communication_NN',
#  'center_NN',
#  ',_,',
#  'the_DT',
#  'throat_NN',
#  'center_NN',
#  '._.',
#  'Just_NNP',
#  'joining_VBG',
#  'in_IN',
#  '?_.',
#  'Read_VB',
#  'about_IN',
#  'the_DT',
#  'first_JJ',
#  ',_,',
#  'second_JJ',
#  ',_,',
#  'third_JJ',
#  'and_CC',
#  'fourth_JJ',
#  'chakras_NNS',
#  '._.',
#  'Chakra_NNP',
#  'author_NN',
#  'Anothea_NNP',
#  'Judith_NNP',
#  'writes_VBZ',
#  ':_:',
#  'Vaguely_RB',
#  'Relephant_JJ',
#  'Reads_NNS',
#  ':_:',
#  'You_PRP',
#  'Don_VBP',
#  '’_JJ',
#  't_NNS',
#  'have_VBP',
#  'to_TO',
#  'be_VB',
#  'an_DT',
#  'Alcoholic_NNP',
#  'to_TO',
#  'be_VB',
#  'Wasted_VBN',
#  '._.',
#  'Read_VB',
#  'How_WRB',
#  'to_TO',
#  'Get_VB',
#  'Over_IN',
#  'the_DT',
#  'One_CD',
#  'you_PRP',
#  'Can_MD',
#  '’_VB',
#  't_JJ',
#  'Get_NNP',
#  'Over_NNP',
#  '._.',
#  'Read_NNP',
#  'Chakra_NNP',
#  'five_CD',
#  'is_VBZ',
#  'the_DT',
#  'center_NN',
#  'related_VBN',
#  'to_TO',
#  'communication_NN',
#  'through_IN',
#  'sound_NN',
#  ',_,',
#  'vibration_NN',
#  ',_,',
#  'self-expression_NN',
#  'and_CC',
#  'creativity_NN',
#  '._.',
#  'It_PRP',
#  'is_VBZ',
#  'the_DT',
#  'realm_NN',
#  'of_IN',
#  'consciousness_NN',
#  'that_WDT',
#  'controls_VBZ',
#  ',_,',
#  'creates_NNS',
#  ',_,',
#  'transmits_NNS',
#  'and_CC',
#  'receives_NNS',
#  'communication_NN',
#  ',_,',
#  'both_DT',
#  'within_IN',
#  'ourselves_PRP',
#  'and_CC',
#  'between_IN',
#  'each_DT',
#  'other_JJ',
#  '._.',
#  'It_PRP',
#  'is_VBZ',
#  'the_DT',
#  'center_NN',
#  'of_IN',
#  'dynamic_JJ',
#  'creativity_NN',
#  ',_,',
#  'of_IN',
#  'synthesizing_VBG',
#  'old_JJ',
#  'ideas_NNS',
#  'into_IN',
#  'something_NN',
#  'new_JJ',
#  '._.',
#  'The_DT',
#  'fifth_JJ',
#  'chakra_NN',
#  'color_NN',
#  'is_VBZ',
#  'bright_JJ',
#  ',_,',
#  'cerulean_JJ',
#  'or_CC',
#  'turquoise_JJ',
#  'blue_NN',
#  '._.',
#  'Some_DT',
#  'symptoms_NNS',
#  'of_IN',
#  'an_DT',
#  'out-of-balance_JJ',
#  'fifth_NN',
#  'chakra_NN',
#  'include_VBP',
#  'suffering_VBG',
#  'from_IN',
#  'throat-centered_JJ',
#  'illnesses_NNS',
#  ',_,',
#  'like_IN',
#  'strep_JJ',
#  'throat_NN',
#  'or_CC',
#  'losing_VBG',
#  'our_PRP$',
#  'voice_NN',
#  '._.',
#  'Throaty_NNP',
#  'ailments_NNS',
#  'may_MD',
#  'mean_VB',
#  'we_PRP',
#  'need_VBP',
#  'to_TO',
#  'slow_VB',
#  'down_RP',
#  ',_,',
#  'rest_NN',
#  'and_CC',
#  'communicate_VB',
#  'more_JJR',
#  'clearly_RB',
#  ',_,',
#  'both_DT',
#  'with_IN',
#  'ourselves_NNS',
#  'and_CC',
#  'others_NNS',
#  ',_,',
#  'or_CC',
#  'they_PRP',
#  'may_MD',
#  'be_VB',
#  'a_DT',
#  'result_NN',
#  'of_IN',
#  'excess_JJ',
#  'communication_NN',
#  'or_CC',
#  'over-sharing—and_VB',
#  'a_DT',
#  'sign_NN',
#  'that_IN',
#  'we_PRP',
#  'should_MD',
#  'give_VB',
#  'our_PRP$',
#  'voice_NN',
#  'a_DT',
#  'break_NN',
#  'and_CC',
#  'intentionally_RB',
#  'soak_VB',
#  'in_IN',
#  'silence_NN',
#  '._.',
#  'If_IN',
#  'our_PRP$',
#  'lives_NNS',
#  'are_VBP',
#  'busy_JJ',
#  ',_,',
#  'we_PRP',
#  'need_VBP',
#  'to_TO',
#  'relax_VB',
#  'and_CC',
#  'remember_VB',
#  'how_WRB',
#  'to_TO',
#  'set_VB',
#  'boundaries_NNS',
#  ',_,',
#  'express_VB',
#  'our_PRP$',
#  'needs_NNS',
#  'and_CC',
#  'allow_VB',
#  'time_NN',
#  'and_CC',
#  'space_NN',
#  'to_TO',
#  'nurture_VB',
#  'ourselves_PRP',
#  '._.',
#  'When_WRB',
#  'our_PRP$',
#  'throat_NN',
#  'chakra_NN',
#  'is_VBZ',
#  'healthy_JJ',
#  'and_CC',
#  'balanced_JJ',
#  ',_,',
#  'we_PRP',
#  'express_VBP',
#  'ourselves_PRP',
#  'and_CC',
#  'communicate_VB',
#  'clearly_RB',
#  ',_,',
#  'honestly_RB',
#  'and_CC',
#  'openly—but_MD',
#  'not_RB',
#  'excessively_RB',
#  '._.',
#  'Here_RB',
#  'are_VBP',
#  'some_DT',
#  'other_JJ',
#  'ways_NNS',
#  'to_TO',
#  'help_VB',
#  'balance_NN',
#  'and_CC',
#  'align_VB',
#  'our_PRP$',
#  'throat_NN',
#  'chakra_NN',
#  ':_:',
#  'Chant_NNP',
#  'Any_NNP',
#  'time_NN',
#  'we_PRP',
#  'speak_VBP',
#  ',_,',
#  'sing_VBG',
#  ',_,',
#  'scream_NN',
#  ',_,',
#  'whisper_NN',
#  'or_CC',
#  'make_VB',
#  'any_DT',
#  'other_JJ',
#  'sort_NN',
#  'of_IN',
#  'sound_NN',
#  'with_IN',
#  'our_PRP$',
#  'voice_NN',
#  ',_,',
#  'we_PRP',
#  'invoke_VBP',
#  'throat_JJ',
#  'energy_NN',
#  '._.',
#  'The_DT',
#  'element_NN',
#  'of_IN',
#  'vishuddha_NN',
#  'chakra_NN',
#  'is_VBZ',
#  'sound_JJ',
#  ',_,',
#  'so_RB',
#  'belt_VBD',
#  'out_RP',
#  'some_DT',
#  'long_JJ',
#  'OMs_NNP',
#  ',_,',
#  'or_CC',
#  'whatever_WDT',
#  'other_JJ',
#  'chants_NNS',
#  'you_PRP',
#  'like_VBP',
#  '._.',
#  'Asana_NNP',
#  'Warm_NNP',
#  'up_RP',
#  'by_IN',
#  'practicing_VBG',
#  'gentle_JJ',
#  'neck_NN',
#  'stretches_NNS',
#  'in_IN',
#  'all_DT',
#  'directions_NNS',
#  '._.',
#  'Many_JJ',
#  'heart_NN',
#  'openers/back_NN',
#  'bends_NNS',
#  'are_VBP',
#  'also_RB',
#  'throat_JJ',
#  'openers_NNS',
#  '._.',
#  'The_DT',
#  'ultimate_NN',
#  'is_VBZ',
#  'probably_RB',
#  'fish_JJ',
#  'pose_NN',
#  '(_(',
#  'matsyasana_NN',
#  ')_)',
#  '._.',
#  'Experiment_NN',
#  'with_IN',
#  'Music_NNP',
#  'Try_NNP',
#  'practicing_VBG',
#  'yoga_NN',
#  'or_CC',
#  'meditation_NN',
#  'to_TO',
#  'healing_VBG',
#  'sounds_NNS',
#  'like_IN',
#  'Tibetan_NNP',
#  'singing_VBG',
#  'bowls_NN',
#  ',_,',
#  'African_NNP',
#  'drums_NNS',
#  ',_,',
#  'ocean_JJ',
#  'waves_NNS',
#  ',_,',
#  'rock_NN',
#  'music—and_NN',
#  'sometimes_RB',
#  'in_IN',
#  'sweet_JJ',
#  'silence_NN',
#  '._.',
#  'Mantra_NNP',
#  'Meditation_NNP',
#  'Perfect_NNP',
#  'for_IN',
#  'sitting_VBG',
#  ',_,',
#  'standing_VBG',
#  'or_CC',
#  'walking_VBG',
#  'meditation_NN',
#  ',_,',
#  'repeating_VBG',
#  'a_DT',
#  'silent_JJ',
#  'mantra_NN',
#  'is_VBZ',
#  'a_DT',
#  'form_NN',
#  'of_IN',
#  'meditation_NN',
#  'that_WDT',
#  'helps_VBZ',
#  'us_PRP',
#  'quickly_RB',
#  'focus_VB',
#  'and_CC',
#  'calm_VB',
#  'the_DT',
#  'mind_NN',
#  '._.',
#  'It_PRP',
#  'can_MD',
#  'be_VB',
#  'a_DT',
#  'syllable_JJ',
#  'sound_NN',
#  'like_IN',
#  '“_NNP',
#  'Om_NNP',
#  '”_NNP',
#  'or_CC',
#  'a_DT',
#  'word_NN',
#  'or_CC',
#  'phrase_NN',
#  'in_IN',
#  'Sanskrit_NNP',
#  ',_,',
#  'English_NNP',
#  'or_CC',
#  'whatever_WDT',
#  'language_NN',
#  'you_PRP',
#  'prefer_VBP',
#  '._.',
#  'A_DT',
#  'nice_JJ',
#  'one_CD',
#  'is_VBZ',
#  '“_JJ',
#  'sat_JJ',
#  'nam_NN',
#  ',_,',
#  '”_NNP',
#  'which_WDT',
#  'means_VBZ',
#  '“_NN',
#  'I_PRP',
#  'am_VBP',
#  'the_DT',
#  'truth_NN',
#  ',_,',
#  '”_NN',
#  'in_IN',
#  'Sanskrit_NNP',
#  ',_,',
#  'but_CC',
#  'there_EX',
#  'are_VBP',
#  'millions_NNS',
#  'to_TO',
#  'choose_VB',
#  'from_IN',
#  '._.',
#  'Mindfully_NNP',
#  'Drink_NNP',
#  'Tea_NNP',
#  'Brew_NNP',
#  'up_RP',
#  'a_DT',
#  'mugful_NN',
#  'of_IN',
#  'your_PRP$',
#  'favorite_JJ',
#  'herbal_JJ',
#  'tea_NN',
#  'and_CC',
#  'have_VB',
#  'your_PRP$',
#  'own_JJ',
#  'little_JJ',
#  'ceremony_NN',
#  'as_IN',
#  'you_PRP',
#  'meditate_VBP',
#  'and_CC',
#  'enjoy_VBP',
#  'a_DT',
#  'delicious_JJ',
#  ',_,',
#  'soothing_VBG',
#  'hot_JJ',
#  'drink_NN',
#  '._.',
#  'Express_NNP',
#  'Yourself_PRP',
#  'Speak_NNP',
#  'up_RP',
#  '!_.',
#  'Share_NNP',
#  'something_NN',
#  'about_IN',
#  'yourself_PRP',
#  'with_IN',
#  'someone_NN',
#  '._.',
#  'Write_VB',
#  'a_DT',
#  'poem_NN',
#  '._.',
#  'Sing_VBG',
#  '._.',
#  'Express_VB',
#  'your_PRP$',
#  'unique_JJ',
#  'voice_NN',
#  'in_IN',
#  'whatever_WDT',
#  'way_NN',
#  'you_PRP',
#  'wish_VBP',
#  '._.',
#  'On_IN',
#  'that_DT',
#  'note_NN',
#  ',_,',
#  'if_IN',
#  'you_PRP',
#  '’_VBP',
#  'd_NNS',
#  'like_IN',
#  'to_TO',
#  'participate_VB',
#  'in_IN',
#  'a_DT',
#  'two-week_JJ',
#  'writing_NN',
#  'challenge_NN',
#  'this_DT',
#  'month_NN',
#  ',_,',
#  'check_VB',
#  'out_RP',
#  'the_DT',
#  'reverb13_NN',
#  'community_NN',
#  'writing_VBG',
#  'project_NN',
#  'happening_VBG',
#  'here_RB',
#  'at_IN',
#  'elephant_NN',
#  '._.']

# %%
tagged_paragraph = ' '.join(words_tags)
tagged_paragraph
# Out:
# 'What_WP are_VBP the_DT qualities_NNS of_IN your_PRP$ voice_NN ?_. The_DT Throat_NNP Center_NNP ._. {_( Chakra_NNP of_IN the_DT Month_NNP }_) Mine_NNP is_VBZ usually_RB calm_JJ ,_, soothing_JJ and_CC clear_JJ ._. Yoga_JJ students_NNS often_RB tell_VBP me_PRP my_PRP$ voice_NN is_VBZ relaxing_VBG ,_, which_WDT is_VBZ a_DT sweet_JJ compliment_NN ._. However_RB ,_, when_WRB I_PRP ’_VBP m_RB caught_VBN up_RP in_IN a_DT moment_NN of_IN anger_NN ,_, fear_NN or_CC stress_NN ,_, my_PRP$ voice_NN can_MD get_VB sharp_JJ and_CC sound_JJ anything_NN but_CC calm_NN and_CC relaxing_NN ._. Let_VB ’_NNP s_VB bring_VBG more_JJR mindfulness_NN to_TO our_PRP$ voices_NNS and_CC how_WRB we_PRP use_VBP them_PRP this_DT month_NN ._. Our_PRP$ December_NNP chakra_NN focus_NN is_VBZ our_PRP$ communication_NN center_NN ,_, the_DT throat_NN center_NN ._. Just_NNP joining_VBG in_IN ?_. Read_VB about_IN the_DT first_JJ ,_, second_JJ ,_, third_JJ and_CC fourth_JJ chakras_NNS ._. Chakra_NNP author_NN Anothea_NNP Judith_NNP writes_VBZ :_: Vaguely_RB Relephant_JJ Reads_NNS :_: You_PRP Don_VBP ’_JJ t_NNS have_VBP to_TO be_VB an_DT Alcoholic_NNP to_TO be_VB Wasted_VBN ._. Read_VB How_WRB to_TO Get_VB Over_IN the_DT One_CD you_PRP Can_MD ’_VB t_JJ Get_NNP Over_NNP ._. Read_NNP Chakra_NNP five_CD is_VBZ the_DT center_NN related_VBN to_TO communication_NN through_IN sound_NN ,_, vibration_NN ,_, self-expression_NN and_CC creativity_NN ._. It_PRP is_VBZ the_DT realm_NN of_IN consciousness_NN that_WDT controls_VBZ ,_, creates_NNS ,_, transmits_NNS and_CC receives_NNS communication_NN ,_, both_DT within_IN ourselves_PRP and_CC between_IN each_DT other_JJ ._. It_PRP is_VBZ the_DT center_NN of_IN dynamic_JJ creativity_NN ,_, of_IN synthesizing_VBG old_JJ ideas_NNS into_IN something_NN new_JJ ._. The_DT fifth_JJ chakra_NN color_NN is_VBZ bright_JJ ,_, cerulean_JJ or_CC turquoise_JJ blue_NN ._. Some_DT symptoms_NNS of_IN an_DT out-of-balance_JJ fifth_NN chakra_NN include_VBP suffering_VBG from_IN throat-centered_JJ illnesses_NNS ,_, like_IN strep_JJ throat_NN or_CC losing_VBG our_PRP$ voice_NN ._. Throaty_NNP ailments_NNS may_MD mean_VB we_PRP need_VBP to_TO slow_VB down_RP ,_, rest_NN and_CC communicate_VB more_JJR clearly_RB ,_, both_DT with_IN ourselves_NNS and_CC others_NNS ,_, or_CC they_PRP may_MD be_VB a_DT result_NN of_IN excess_JJ communication_NN or_CC over-sharing—and_VB a_DT sign_NN that_IN we_PRP should_MD give_VB our_PRP$ voice_NN a_DT break_NN and_CC intentionally_RB soak_VB in_IN silence_NN ._. If_IN our_PRP$ lives_NNS are_VBP busy_JJ ,_, we_PRP need_VBP to_TO relax_VB and_CC remember_VB how_WRB to_TO set_VB boundaries_NNS ,_, express_VB our_PRP$ needs_NNS and_CC allow_VB time_NN and_CC space_NN to_TO nurture_VB ourselves_PRP ._. When_WRB our_PRP$ throat_NN chakra_NN is_VBZ healthy_JJ and_CC balanced_JJ ,_, we_PRP express_VBP ourselves_PRP and_CC communicate_VB clearly_RB ,_, honestly_RB and_CC openly—but_MD not_RB excessively_RB ._. Here_RB are_VBP some_DT other_JJ ways_NNS to_TO help_VB balance_NN and_CC align_VB our_PRP$ throat_NN chakra_NN :_: Chant_NNP Any_NNP time_NN we_PRP speak_VBP ,_, sing_VBG ,_, scream_NN ,_, whisper_NN or_CC make_VB any_DT other_JJ sort_NN of_IN sound_NN with_IN our_PRP$ voice_NN ,_, we_PRP invoke_VBP throat_JJ energy_NN ._. The_DT element_NN of_IN vishuddha_NN chakra_NN is_VBZ sound_JJ ,_, so_RB belt_VBD out_RP some_DT long_JJ OMs_NNP ,_, or_CC whatever_WDT other_JJ chants_NNS you_PRP like_VBP ._. Asana_NNP Warm_NNP up_RP by_IN practicing_VBG gentle_JJ neck_NN stretches_NNS in_IN all_DT directions_NNS ._. Many_JJ heart_NN openers/back_NN bends_NNS are_VBP also_RB throat_JJ openers_NNS ._. The_DT ultimate_NN is_VBZ probably_RB fish_JJ pose_NN (_( matsyasana_NN )_) ._. Experiment_NN with_IN Music_NNP Try_NNP practicing_VBG yoga_NN or_CC meditation_NN to_TO healing_VBG sounds_NNS like_IN Tibetan_NNP singing_VBG bowls_NN ,_, African_NNP drums_NNS ,_, ocean_JJ waves_NNS ,_, rock_NN music—and_NN sometimes_RB in_IN sweet_JJ silence_NN ...
